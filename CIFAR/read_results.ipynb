# %%
import numpy as np
print('Reporting (mean, std-dev (not std-err), number of runs) for given configuration.')

#the results will be grouped by the Parameters below
selected_hps = ['method','evaluate_on_validation', 're_init_model', 'rescale', 'batch_size'] 
#for each group as determined above, the runs which agree in the HPs below 
#will be grouped together and average + std of this group will be reported
listed_hps = ['c'] 

#filt can serve as a filter to only show results with a certain property. 
# filter for example for validation results or test results
filt = [('evaluate_on_validation','False')]
if not filt == []:
    print('\nOnly results satisfying the following are included:')
    print(filt)
    print('\n\n')



#choose the file to open
with open('summary_SI.txt', 'r') as f:
    contents = f.read()
dict_all = {}

for run in contents.split('\n'):
    if run == '':
        break  
    #print(run.split(' '))    
    result, hps = run.split(' ')
    hps = hps.split('__')
    hps2 = hps.copy()
    hps_dict = {}
    hps_show = []
    for item in hps:
        item = item.split('=')
        if item[0] in selected_hps:
            hps_dict[item[0]]=item[1]
        if item[0] in listed_hps:
            #hps_show.append(item[1])
            hps_show.append(item[0]+'='+item[1])
    cont = True
    for x in filt:
        cont = cont and (hps_dict[x[0]]==x[1])
    if cont:    
        hp_list = tuple(hps_dict.values())
        hp_list = []
        for item2 in hps_dict.items():
            hp_list.append(str(item2[0])+'='+str(item2[1]))

        hp_list = tuple(sorted(hp_list))
        if hp_list not in dict_all:
            dict_all[hp_list] = {}
        if tuple(hps_show) not in dict_all[hp_list]:
            dict_all[hp_list][tuple(hps_show)] = []
        dict_all[hp_list][tuple(hps_show)].append(float(result))

for config in dict_all.items():    
    summary = []    
    for item in config[1].items():
        #print(item[0])
        #print(item[1])
        summary.append( (item[0], 100*np.mean(item[1]), 100*np.std(item[1]), len(item[1])) )
    summary = sorted(summary, key=lambda x: x[1])
    print('\n',config[0])
    [print(x) for x in summary]
# Out:
# Reporting (mean, std-dev (not std-err), number of runs) for given configuration.
#
# Only results satisfying the following are included:
# [('evaluate_on_validation', 'False')]
#
#
#
#
#  ('batch_size=256', 'evaluate_on_validation=False', 'method=SI', 're_init_model=True', 'rescale=1.0')
# (('c=5.0',), 73.88166785240173, 0.0, 1)
#
#  ('batch_size=256', 'evaluate_on_validation=False', 'method=SIB', 're_init_model=True', 'rescale=1.0')
# (('c=5.0',), 75.21666586399078, 0.0, 1)
#
#  ('batch_size=256', 'evaluate_on_validation=False', 'method=SIU', 're_init_model=False', 'rescale=1.0')
# (('c=2.0',), 73.53166739145914, 0.0, 1)
#
#  ('batch_size=256', 'evaluate_on_validation=False', 'method=SOS', 're_init_model=True', 'rescale=0.0')
# (('c=500.0',), 74.35999910036722, 0.0, 1)
#
#  ('batch_size=2048', 'evaluate_on_validation=False', 'method=SI', 're_init_model=True', 'rescale=1.0')
# (('c=20.0',), 70.2266663312912, 0.0, 1)
#
#  ('batch_size=2048', 'evaluate_on_validation=False', 'method=SOS', 're_init_model=True', 'rescale=0.0')
# (('c=2000.0',), 74.84500110149384, 0.0, 1)
